# %% [markdown]
# # Subplots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from math import ceil

# %%
data = sns.load_dataset("iris")
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
ncol = 10
nrow = 5
print(f"{ncol=}, {nrow=}, {nrow*ncol=}")
# Out:
# ncol=10, nrow=5, nrow*ncol=50

# %%
## suplots
fig, axs = plt.subplots(nrow, ncol ,figsize=(15,5))
axs = axs.reshape(-1)       ## flat axes
for i,ax in enumerate(axs):
    plt.text(0.5, 0.5
            , str(i)
            , horizontalalignment='center',verticalalignment='center'
            , transform=ax.transAxes
        )
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dherrera\AppData\Local\Temp\ipykernel_10548\3814509904.py:12: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %% [markdown]
# Remove subplots

# %%
## suplots
fig, axs = plt.subplots(nrow, ncol ,figsize=(15,5))
axs = axs.reshape(-1)       ## flat axes
for i,ax in enumerate(axs):
    plt.text(0.5, 0.5
            , str(i)
            , horizontalalignment='center',verticalalignment='center'
            , transform=ax.transAxes
        )
    ax.set_xticks([])
    ax.set_yticks([])
# subplots to remove
for i in range(0,ncol*nrow,3):
    axs[i].axis('off')
fig.suptitle("remove every 3 subplots", fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dherrera\AppData\Local\Temp\ipykernel_10548\1528933726.py:16: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %% [markdown]
# set label to only one subplot

# %%
## suplots
fig, axs = plt.subplots(nrow, ncol ,figsize=(15,5))
axs = axs.reshape(-1)       ## flat axes
for i,ax in enumerate(axs):
    plt.text(0.5, 0.5
            , str(i)
            , horizontalalignment='center',verticalalignment='center'
            , transform=ax.transAxes
        )
    sns.scatterplot(data=data, x="sepal_length", y="sepal_width", hue="species", ax=ax)
    ax.set_xticks([])
    ax.set_yticks([])
fig.suptitle("remove every 3 subplots", fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dherrera\AppData\Local\Temp\ipykernel_10548\2262520000.py:14: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()
